# %%
#aula 41 -> Engenharia de atributos

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df_obj = pd.read_csv("credit_simple.csv", sep = ';')
df_obj.shape
# Out:
# (1000, 8)

# %%
df_obj.head(6)
# Out:
#    SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO        DATA  \
# 0       1169.0                4     67           nenhum  01/01/2019
# 1       5951.0                2     22           nenhum  01/01/2020
# 2       2096.0                3     49           nenhum  02/01/2020
# 3       7882.0                4     45           nenhum  02/01/2019
# 4       4870.0                4     53           nenhum  03/01/2018
# 5       9055.0                4     35           nenhum  04/01/2020
#
#           ESTADOCIVIL            PROPOSITO CLASSE
# 0  masculino solteiro             radio/tv    bom
# 1         fem div/cas             radio/tv   ruim
# 2  masculino solteiro             educação    bom
# 3  masculino solteiro  mobilia/equipamento    bom
# 4  masculino solteiro           carro novo   ruim
# 5  masculino solteiro             educação    bom

# %%
y = df_obj['CLASSE']
x = df_obj.iloc[:,:-1]

# %%
x.isnull().sum()
# Out:
# SALDO_ATUAL         7
# RESIDENCIADESDE     0
# IDADE               0
# OUTROSPLANOSPGTO    0
# DATA                0
# ESTADOCIVIL         8
# PROPOSITO           0
# dtype: int64

# %%
#coloque a mediana como valor central [- sensivel a outliers do que a media]
#coloque a mediana no lugar dos na de valores numericos

# %%
mediana = x['SALDO_ATUAL'].median()
mediana
# Out:
# 2323.0

# %%
x['SALDO_ATUAL'].fillna(mediana, inplace = True)
x.isnull().sum()
# Out:
# <ipython-input-11-a57a2315a12d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x['SALDO_ATUAL'].fillna(mediana, inplace = True)
# SALDO_ATUAL         0
# RESIDENCIADESDE     0
# IDADE               0
# OUTROSPLANOSPGTO    0
# DATA                0
# ESTADOCIVIL         8
# PROPOSITO           0
# dtype: int64

# %%
agrupado = x.groupby(['ESTADOCIVIL']).size()
agrupado
# Out:
# ESTADOCIVIL
# fem div/cas               308
# masculino casado/viuvo     92
# masculino div/sep          50
# masculino solteiro        542
# dtype: int64

# %%
#trocar valores categoricos pela moda

# %%
x['ESTADOCIVIL'].fillna('masculino solteiro', inplace = True)
x.isnull().sum()
# Out:
# <ipython-input-13-d9d271f9fc17>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x['ESTADOCIVIL'].fillna('masculino solteiro', inplace = True)
# SALDO_ATUAL         0
# RESIDENCIADESDE     0
# IDADE               0
# OUTROSPLANOSPGTO    0
# DATA                0
# ESTADOCIVIL         0
# PROPOSITO           0
# dtype: int64

# %%
desv = x['SALDO_ATUAL'].std()
desv
# Out:
# 685936688.9820064

# %%
x.loc[x['SALDO_ATUAL']>=2*desv, 'SALDO_ATUAL']
# Out:
# 127    2.541111e+09
# 160    2.154441e+10
# Name: SALDO_ATUAL, dtype: float64

# %%
mediana = x['SALDO_ATUAL'].median()
mediana
# Out:
# 2323.0

# %%
x.loc[x['SALDO_ATUAL'] >= 2*desv, "SALDO_ATUAL"] = mediana
x.loc[x['SALDO_ATUAL'] >= 2*desv]
# Out:
# Empty DataFrame
# Columns: [SALDO_ATUAL, RESIDENCIADESDE, IDADE, OUTROSPLANOSPGTO, DATA, ESTADOCIVIL, PROPOSITO]
# Index: []

# %% [markdown]
# #Aula 42 --> Data Binding

# %%
agrupado = x.groupby(['PROPOSITO']).size()
agrupado
# Out:
# PROPOSITO
# Eletrodomésticos        12
# carro novo             234
# carro usado            103
# educação                50
# mobilia/equipamento    181
# negócios                97
# obras                   22
# outros                  12
# qualificação             9
# radio/tv               280
# dtype: int64

# %%
x.loc[x['PROPOSITO'] == 'Eletrodomesticos', 'PROPOSITO'] = 'outros'
x.loc[x['PROPOSITO'] == 'qualificação', 'PROPOSITO'] = 'outros'
agrupado = x.groupby(['PROPOSITO']).size()
agrupado
# Out:
# PROPOSITO
# Eletrodomésticos        12
# carro novo             234
# carro usado            103
# educação                50
# mobilia/equipamento    181
# negócios                97
# obras                   22
# outros                  21
# radio/tv               280
# dtype: int64

# %%
x['DATA'] #varias informaçoes podemos extrai de uma simples data
# Out:
# 0      01/01/2019
# 1      01/01/2020
# 2      02/01/2020
# 3      02/01/2019
# 4      03/01/2018
#           ...
# 995    29/06/2018
# 996    30/06/2018
# 997    03/07/2018
# 998    04/07/2019
# 999    05/07/2018
# Name: DATA, Length: 1000, dtype: object

# %%
x['DATA'] = pd.to_datetime(x['DATA'], format = '%d/%m/%Y')

# %%
x['DATA']
# Out:
# 0     2019-01-01
# 1     2020-01-01
# 2     2020-01-02
# 3     2019-01-02
# 4     2018-01-03
#          ...
# 995   2018-06-29
# 996   2018-06-30
# 997   2018-07-03
# 998   2019-07-04
# 999   2018-07-05
# Name: DATA, Length: 1000, dtype: datetime64[ns]

# %%
x['ANO'] = x['DATA'].dt.year
x['MES'] = x['DATA'].dt.month
x['DIASEMANA'] = x['DATA'].dt.day_name()

# %%
x['DIASEMANA']
# Out:
# 0        Tuesday
# 1      Wednesday
# 2       Thursday
# 3      Wednesday
# 4      Wednesday
#          ...
# 995       Friday
# 996     Saturday
# 997      Tuesday
# 998     Thursday
# 999     Thursday
# Name: DIASEMANA, Length: 1000, dtype: object

# %%
x['ESTADOCIVIL'].unique()
# Out:
# array(['masculino solteiro', 'fem div/cas', 'masculino div/sep',
#        'masculino casado/viuvo'], dtype=object)

# %%
x['PROPOSITO'].unique()
# Out:
# array(['radio/tv', 'educação', 'mobilia/equipamento', 'carro novo',
#        'carro usado', 'negócios', 'Eletrodomésticos', 'obras', 'outros'],
#       dtype=object)

# %%
x['DIASEMANA'].unique()
# Out:
# array(['Tuesday', 'Wednesday', 'Thursday', 'Saturday', 'Sunday', 'Monday',
#        'Friday'], dtype=object)

# %%
labelencoder1 = LabelEncoder()
x['ESTADOCIVIL'] = labelencoder1.fit_transform(x['ESTADOCIVIL'])
x['PROPOSITO'] = labelencoder1.fit_transform(x['PROPOSITO'])
x['DIASEMANA'] = labelencoder1.fit_transform(x['DIASEMANA'])

# %%
x.head(6)
# Out:
#    SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO       DATA  \
# 0       1169.0                4     67           nenhum 2019-01-01
# 1       5951.0                2     22           nenhum 2020-01-01
# 2       2096.0                3     49           nenhum 2020-01-02
# 3       7882.0                4     45           nenhum 2019-01-02
# 4       4870.0                4     53           nenhum 2018-01-03
# 5       9055.0                4     35           nenhum 2020-01-04
#
#    ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA
# 0            3          8  2019    1          5
# 1            0          8  2020    1          6
# 2            3          3  2020    1          4
# 3            3          4  2019    1          6
# 4            3          1  2018    1          6
# 5            3          3  2020    1          2

# %%
outros = x['OUTROSPLANOSPGTO'].unique()
outros
# Out:
# array(['nenhum', 'banco', 'stores'], dtype=object)

# %%
z = pd.get_dummies(x['OUTROSPLANOSPGTO'], prefix = 'OUTROS')

# %%
z
# Out:
#      OUTROS_banco  OUTROS_nenhum  OUTROS_stores
# 0           False           True          False
# 1           False           True          False
# 2           False           True          False
# 3           False           True          False
# 4           False           True          False
# ..            ...            ...            ...
# 995         False           True          False
# 996         False           True          False
# 997         False           True          False
# 998         False           True          False
# 999         False           True          False
#
# [1000 rows x 3 columns]

# %%
x
# Out:
#      SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO       DATA  \
# 0         1169.0                4     67           nenhum 2019-01-01
# 1         5951.0                2     22           nenhum 2020-01-01
# 2         2096.0                3     49           nenhum 2020-01-02
# 3         7882.0                4     45           nenhum 2019-01-02
# 4         4870.0                4     53           nenhum 2018-01-03
# ..           ...              ...    ...              ...        ...
# 995       1736.0                4     31           nenhum 2018-06-29
# 996       3857.0                4     40           nenhum 2018-06-30
# 997        804.0                4     38           nenhum 2018-07-03
# 998       1845.0                4     23           nenhum 2019-07-04
# 999       4576.0                4     27           nenhum 2018-07-05
#
#      ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA
# 0              3          8  2019    1          5
# 1              0          8  2020    1          6
# 2              3          3  2020    1          4
# 3              3          4  2019    1          6
# 4              3          1  2018    1          6
# ..           ...        ...   ...  ...        ...
# 995            0          4  2018    6          0
# 996            2          2  2018    6          2
# 997            3          8  2018    7          5
# 998            3          8  2019    7          4
# 999            3          2  2018    7          4
#
# [1000 rows x 10 columns]

# %% [markdown]
# <h3 style = 'background-color:yellow;'>Standard Scaler</h3>

# %%
sc = StandardScaler()
m = sc.fit_transform(x.iloc[:,0:3])
m
# Out:
# array([[-0.74551643,  1.04698668,  1.6392759 ],
#        [ 0.95774038, -0.76597727, -0.74024139],
#        [-0.41533679,  0.14050471,  0.68746898],
#        ...,
#        [-0.87552244,  1.04698668,  0.1058092 ],
#        [-0.50473818,  1.04698668, -0.68736323],
#        [ 0.46799171,  1.04698668, -0.47585058]])

# %%
x = pd.concat([x,z,pd.DataFrame(m, columns = [['SALDO_ATUAL_N','RESIDENCEADESDE_N', 'IDADE_N']])], axis=1)

# %%
x.head(6)
# Out:
#    SALDO_ATUAL  RESIDENCIADESDE  IDADE OUTROSPLANOSPGTO       DATA  \
# 0       1169.0                4     67           nenhum 2019-01-01
# 1       5951.0                2     22           nenhum 2020-01-01
# 2       2096.0                3     49           nenhum 2020-01-02
# 3       7882.0                4     45           nenhum 2019-01-02
# 4       4870.0                4     53           nenhum 2018-01-03
# 5       9055.0                4     35           nenhum 2020-01-04
#
#    ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA  OUTROS_banco  OUTROS_nenhum  \
# 0            3          8  2019    1          5         False           True
# 1            0          8  2020    1          6         False           True
# 2            3          3  2020    1          4         False           True
# 3            3          4  2019    1          6         False           True
# 4            3          1  2018    1          6         False           True
# 5            3          3  2020    1          2         False           True
#
#    OUTROS_stores  (SALDO_ATUAL_N,)  (RESIDENCEADESDE_N,)  (IDADE_N,)
# 0          False         -0.745516              1.046987    1.639276
# 1          False          0.957740             -0.765977   -0.740241
# 2          False         -0.415337              0.140505    0.687469
# 3          False          1.645526              1.046987    0.475956
# 4          False          0.572709              1.046987    0.898982
# 5          False          2.063326              1.046987   -0.052825

# %%
x.drop(columns = ['SALDO_ATUAL', 'RESIDENCIADESDE', 'IDADE', 'OUTROSPLANOSPGTO', 'DATA', 'OUTROS_banco'], inplace = True)

# %%
x
# Out:
#      ESTADOCIVIL  PROPOSITO   ANO  MES  DIASEMANA  OUTROS_nenhum  \
# 0              3          8  2019    1          5           True
# 1              0          8  2020    1          6           True
# 2              3          3  2020    1          4           True
# 3              3          4  2019    1          6           True
# 4              3          1  2018    1          6           True
# ..           ...        ...   ...  ...        ...            ...
# 995            0          4  2018    6          0           True
# 996            2          2  2018    6          2           True
# 997            3          8  2018    7          5           True
# 998            3          8  2019    7          4           True
# 999            3          2  2018    7          4           True
#
#      OUTROS_stores  (SALDO_ATUAL_N,)  (RESIDENCEADESDE_N,)  (IDADE_N,)
# 0            False         -0.745516              1.046987    1.639276
# 1            False          0.957740             -0.765977   -0.740241
# 2            False         -0.415337              0.140505    0.687469
# 3            False          1.645526              1.046987    0.475956
# 4            False          0.572709              1.046987    0.898982
# ..             ...               ...                   ...         ...
# 995          False         -0.543562              1.046987   -0.264338
# 996          False          0.211898              1.046987    0.211566
# 997          False         -0.875522              1.046987    0.105809
# 998          False         -0.504738              1.046987   -0.687363
# 999          False          0.467992              1.046987   -0.475851
#
# [1000 rows x 10 columns]
